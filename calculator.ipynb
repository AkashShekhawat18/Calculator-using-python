# %%
a=int(input("write a number1"))
b=int(input("write a number1"))
c=input("add symbol")
if c=='+':
    print(a+b)
elif c=='-':
    print(a-b)
elif c=='*':
    print(a*b)
elif c=='/':
    print(a/b)
else:
    print("invalid symbol")
# Out:
# write a number1 2332
# write a number1 23
# add symbol +
# 233223
